# %% [markdown]
# # WFP Draft Retirement: Luxembourg School Case
#
# This notebook is the migration note created before removing `Research-Sandbox/drafts/WFP` from Git. The WFP draft has been superseded by `Research-Sandbox/scalable_general_distances_per_country`.
#
# The original Luxembourg school-case notebook is preserved here in the promoted package as `notebooks/luxembourg_school_case_architecture.ipynb`. This retirement notebook records where the case moved, what changed, and the API/CLI entry points that should be used going forward.

# %% [markdown]
# ## Replacement Map
#
# | Old WFP path | Replacement in promoted package |
# | --- | --- |
# | `drafts/WFP/notebooks/luxembourg_school_case_architecture.ipynb` | `scalable_general_distances_per_country/notebooks/luxembourg_school_case_architecture.ipynb` |
# | `drafts/WFP/src/wfp_access` | `scalable_general_distances_per_country/src/scalable_distances` |
# | `wfp_access.manifest` | `scalable_distances.manifest` |
# | draft routing placeholders | lazy `NetworkXRouter` and `PandanaRouter` strategies |
# | WFP shared-cache validation docs | scalable shared-cache validation docs and consistency note |

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0]
SRC_ROOT = PROJECT_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from scalable_distances import describe_backends, describe_country_sources

describe_backends()

# %%
describe_country_sources(
    country_slug="luxembourg",
    iso3="LUX",
    base_dir=Path(r"C:\\local\\Download_Depot\\luxembourg_data"),
    worldpop_dataset="global1",
    worldpop_year=2020,
)

# %% [markdown]
# ## How To Re-run The Case
#
# Use the promoted notebook:
#
# `Research-Sandbox/scalable_general_distances_per_country/notebooks/luxembourg_school_case_architecture.ipynb`
#
# For API-first use, import from `scalable_distances`. For CLI use, run from `Research-Sandbox/scalable_general_distances_per_country/src` or install the package in editable mode.
