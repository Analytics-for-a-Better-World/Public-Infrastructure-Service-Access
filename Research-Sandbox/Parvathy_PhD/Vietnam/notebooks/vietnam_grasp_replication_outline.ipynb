# %% [markdown]
# # Vietnam Fresh-PISA Replication Outline
#
# This notebook intentionally ignores Fleur's old npy/pickle data. Build instances from PISA parquets with `scripts/build_pisa_instance.py`, then run `scripts/run_vietnam_grasp_experiments.py`.

# %%
from pathlib import Path
ROOT = Path(r'C:/local/GIT/Public-Infrastructure-Service-Access/Research-Sandbox/Parvathy_PhD/Vietnam')
OUTPUT = Path(r'C:/local/Parvathy/Vietnam')
ROOT, OUTPUT
