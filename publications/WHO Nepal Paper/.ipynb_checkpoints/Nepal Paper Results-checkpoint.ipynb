# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import geopandas as gpd
import requests

import shapely
from shapely.geometry import Polygon, Point
from shapely.ops import cascaded_union
import shapely.speedups

shapely.speedups.enable()

import folium
from folium.plugins import MeasureControl

import plotly.express as px

pd.set_option('display.max_rows', 500)

# %% [markdown]
# In May 2021, Nepal had a limited number of COVID-19 test labs, with only 69 operational facilities. By November 2021, the number increased to 89. This study aimed to assess the impact of the opening of COVID-19 test labs on the physical accessibility of vulnerable populations in Nepal. By combining public data from the Ministry of Health and Population (MoHP) with global datasets on population, healthcare centers, travel time, and relative wealth index, this research aimed to provide critical insights on optimizing the location of testing facilities using open data and optimization models, with a focus on confronting unprecedented pandemics such as COVID-19.

# %%
existing_labs = pd.read_csv('Data/laboratory_geocoded.csv')
existing_labs = existing_labs[['Unnamed: 0','lng','lat','Laboratory']]
existing_labs.columns = ['index','LONG','LAT','L_NAME']
current_hospitals = existing_labs[['index','LONG','LAT','L_NAME']].drop_duplicates()
current_hospitals.columns = ['Hosp_ID','Longitude','Latitude','L_NAME']

df_lab_open_dates = pd.read_excel('Data/tests_per_lab.xlsx')[['Date','Laboratory','Province Name']]
df_open_dates = df_lab_open_dates.groupby(['Laboratory','Province Name'])['Date'].min().reset_index()
df_open_dates.columns = ['L_NAME','Province','Date Open']

# %%
existing_labs = pd.merge(current_hospitals,df_open_dates,on='L_NAME')

def convert_point(df):
    lat = df['Latitude']
    lon = df['Longitude']
    return(Point(lon,lat))

existing_labs['geometry'] = existing_labs[['Latitude','Longitude']].apply(convert_point,axis=1)

existing_labs.head(2)
# Out:
#    Hosp_ID  Longitude   Latitude
# 0        0  87.268361  26.812242  \
# 1        1  87.285188  26.459050
#
#                                               L_NAME    Province  Date Open
# 0  B. P. Koirala Institute of Health Sciences, Dh...  Province 1 2021-05-01  \
# 1                         Koshi Hospital, Biratnagar  Province 1 2021-05-01
#
#                         geometry
# 0  POINT (87.2683609 26.8122418)
# 1  POINT (87.2851884 26.4590497)

# %%
# %%time
population = pd.read_csv(r'Data/ppp_NPL_2020_1km_Aggregated_UNadj.csv').reset_index()
population.columns = ['ID','xcoord','ycoord','household_count']
population['xcoord'] = population['xcoord'].round(2)
population['ycoord'] = population['ycoord'].round(2)

population = population.groupby(['xcoord','ycoord'])['household_count'].sum().reset_index().reset_index()
population['household_count'] = population['household_count'].round()
population.columns = ['ID','xcoord','ycoord','population']

def convert_Point(population):
    return Point(population['xcoord'],population['ycoord'])
population['geometry'] = population[['ycoord','xcoord']].apply(convert_Point,axis=1)
population = gpd.GeoDataFrame(population)
# Out:
# CPU times: user 7.85 s, sys: 112 ms, total: 7.96 s
# Wall time: 8.05 s

# %%
print('Total Population:',round(population['population'].sum()/1000000,2),'million')
# Out:
# Total Population: 29.14 million

# %%
districts_nepal = gpd.read_file('Data/shapefile_nepal_districts.geojson')
population = gpd.sjoin(population, districts_nepal, how="left", op="within")

# %%
access_token = "pk.eyJ1IjoicGFydmF0aHlrcmlzaG5hbmthYnciLCJhIjoiY2xqZXlna2VtMDFyOTNrbThqcnE2ZWx2ZiJ9.fwUyC3lZIYnj9hoEwgywHQ"

# %%
def get_isochrone(df,minutes_list,access_token,mode):
    longitude = df['Longitude']
    latitude = df['Latitude']
    query = """https://api.mapbox.com/isochrone/v1/mapbox/"""
    query = query+mode+'/'
    query = query+str(longitude)+','+str(latitude)+'?'
    query = query+'contours_minutes='+minutes_list
    query = query+'&polygons=true&access_token='
    query = query+access_token
    req_return = (requests.get(query).json())
    #print(req_return)
    return(req_return['features'])

# %%
def get_pop_count(x):
    pop_count = population[population['ID'].isin(x)]['population'].sum()
    return pop_count

# %%
# %%time

existing_labs['isochrone_60min_driving'] = existing_labs[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="60",
                                                                                   access_token=access_token,
                                                                                   mode='driving',
                                                                                   axis=1)

existing_labs['isochrone_30min_driving'] = existing_labs[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="30",
                                                                                   access_token=access_token,
                                                                                   mode='driving',
                                                                                   axis=1)

existing_labs['isochrone_60min_walking'] = existing_labs[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="60",
                                                                                   access_token=access_token,
                                                                                   mode='walking',
                                                                                   axis=1)

existing_labs['isochrone_30min_walking'] = existing_labs[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="30",
                                                                                   access_token=access_token,
                                                                                   mode='walking',
                                                                                   axis=1)
# Out:
# CPU times: user 5.65 s, sys: 583 ms, total: 6.23 s
# Wall time: 25.2 s

# %%
# %%time

existing_labs['60min_driving'] = existing_labs['isochrone_60min_driving'].apply(lambda x: x[0]['geometry'])
existing_labs['60min_driving'] = existing_labs['60min_driving'].apply(lambda x:Polygon(x['coordinates'][0]))

existing_labs['30min_driving'] = existing_labs['isochrone_30min_driving'].apply(lambda x: x[0]['geometry'])
existing_labs['30min_driving'] = existing_labs['30min_driving'].apply(lambda x:Polygon(x['coordinates'][0]))

existing_labs['60min_walking'] = existing_labs['isochrone_60min_walking'].apply(lambda x: x[0]['geometry'])
existing_labs['60min_walking'] = existing_labs['60min_walking'].apply(lambda x:Polygon(x['coordinates'][0]))

existing_labs['30min_walking'] = existing_labs['isochrone_30min_walking'].apply(lambda x: x[0]['geometry'])
existing_labs['30min_walking'] = existing_labs['30min_walking'].apply(lambda x:Polygon(x['coordinates'][0]))
# Out:
# CPU times: user 21.7 ms, sys: 3.99 ms, total: 25.7 ms
# Wall time: 23.6 ms

# %%
def get_population_within_vector(vector_polygon,vector_layer):
    pip_mask = vector_layer.within(vector_polygon)
    pip_data = vector_layer.loc[pip_mask]
    return(list(pip_data['ID'].unique()))

# %%
# %%time

existing_labs['ID_60min_driving'] = existing_labs['60min_driving'].apply(get_population_within_vector,vector_layer=population)
existing_labs['ID_30min_driving'] = existing_labs['30min_driving'].apply(get_population_within_vector,vector_layer=population)
existing_labs['ID_60min_walking'] = existing_labs['60min_walking'].apply(get_population_within_vector,vector_layer=population)
existing_labs['ID_30min_walking'] = existing_labs['30min_walking'].apply(get_population_within_vector,vector_layer=population)
# Out:
# CPU times: user 19 s, sys: 70.4 ms, total: 19 s
# Wall time: 19.1 s

# %%
selected_hosp = existing_labs['L_NAME'].unique()[4]
selected_hosp
# Out:
# 'Nobel Medical College Teaching Hospital,Biratnagar'

# %%
start_coords = (28.4939,84.1240)
folium_map = folium.Map(location=start_coords, zoom_start=5)

test_ids = existing_labs[existing_labs['L_NAME']==selected_hosp]


for i in range(0,len(test_ids)):
    folium.Marker([test_ids.iloc[i]['Latitude'], test_ids.iloc[i]['Longitude']],
                        color='blue',popup=test_ids.iloc[i]['L_NAME']).add_to(folium_map)
    
    geo_j = folium.GeoJson(data=test_ids.iloc[i]['60min_driving'],style_function=lambda x:{'color': 'red'})
    folium.Popup(test_ids.iloc[i]['L_NAME']).add_to(geo_j)
    geo_j.add_to(folium_map)
    
    geo_j = folium.GeoJson(data=test_ids.iloc[i]['30min_driving'],style_function=lambda x:{'color': 'cyan'})
    folium.Popup(test_ids.iloc[i]['L_NAME']).add_to(geo_j)
    geo_j.add_to(folium_map)
    
    geo_j = folium.GeoJson(data=test_ids.iloc[i]['60min_walking'],style_function=lambda x:{'color': 'blue'})
    folium.Popup(test_ids.iloc[i]['L_NAME']).add_to(geo_j)
    geo_j.add_to(folium_map)
    
    geo_j = folium.GeoJson(data=test_ids.iloc[i]['30min_walking'],style_function=lambda x:{'color': 'green'})
    folium.Popup(test_ids.iloc[i]['L_NAME']).add_to(geo_j)
    geo_j.add_to(folium_map)
    
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_985458bac1950cc9bfd13d227693439b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_985458bac1950cc9bfd13d227693439b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_985458bac1950cc9bfd13d227693439b = L.map(
#                 &quot;map_985458bac1950cc9bfd13d227693439b&quot;,
#                 {
#                     center: [28.4939, 84.124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0d17604425dae07f825b677aa6146ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_985458bac1950cc9bfd13d227693439b);
#
#
#             var marker_95d1a03e583af15b10faeaa72eafe0a9 = L.marker(
#                 [26.4896614, 87.2702268],
#                 {&quot;color&quot;: &quot;blue&quot;}
#             ).addTo(map_985458bac1950cc9bfd13d227693439b);
#
#
#         var popup_f58464b2065fc43dd586867cbd0e3da9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27c77fb7427164b9fda2f26712b83e41 = $(`&lt;div id=&quot;html_27c77fb7427164b9fda2f26712b83e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nobel Medical College Teaching Hospital,Biratnagar&lt;/div&gt;`)[0];
#                 popup_f58464b2065fc43dd586867cbd0e3da9.setContent(html_27c77fb7427164b9fda2f26712b83e41);
#
#
#
#         marker_95d1a03e583af15b10faeaa72eafe0a9.bindPopup(popup_f58464b2065fc43dd586867cbd0e3da9)
#         ;
#
#
#
#
#         function geo_json_d7c80d52120169776abbe5988297a446_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_d7c80d52120169776abbe5988297a446_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d7c80d52120169776abbe5988297a446 = L.geoJson(null, {
#                 onEachFeature: geo_json_d7c80d52120169776abbe5988297a446_onEachFeature,
#
#                 style: geo_json_d7c80d52120169776abbe5988297a446_styler,
#         });
#
#         function geo_json_d7c80d52120169776abbe5988297a446_add (data) {
#             geo_json_d7c80d52120169776abbe5988297a446
#                 .addData(data)
#                 .addTo(map_985458bac1950cc9bfd13d227693439b);
#         }
#             geo_json_d7c80d52120169776abbe5988297a446_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[87.302227, 26.814484], [87.287048, 26.81684], [87.279502, 26.813661], [87.274227, 26.815182], [87.270089, 26.813661], [87.269409, 26.808843], [87.272576, 26.801661], [87.272412, 26.791847], [87.274227, 26.79094], [87.278227, 26.794372], [87.279456, 26.79089], [87.282605, 26.79004], [87.283307, 26.786742], [87.286674, 26.785661], [87.286573, 26.769315], [87.282899, 26.76899], [87.282563, 26.765661], [87.282501, 26.741661], [87.278763, 26.741125], [87.278481, 26.729661], [87.274646, 26.729242], [87.272899, 26.726989], [87.270534, 26.717355], [87.266227, 26.725468], [87.262227, 26.721328], [87.258227, 26.721806], [87.254227, 26.724836], [87.249855, 26.722033], [87.249265, 26.717661], [87.243857, 26.709661], [87.243201, 26.704687], [87.233724, 26.705159], [87.234633, 26.709661], [87.230227, 26.712195], [87.224507, 26.709661], [87.222227, 26.704446], [87.22008, 26.705661], [87.219517, 26.710952], [87.214292, 26.713727], [87.214227, 26.719199], [87.210227, 26.720327], [87.20864, 26.724075], [87.202227, 26.726052], [87.198227, 26.731399], [87.194102, 26.733786], [87.191651, 26.729661], [87.192841, 26.725661], [87.196653, 26.721661], [87.197653, 26.713661], [87.195727, 26.709661], [87.200786, 26.705661], [87.2047, 26.696134], [87.210664, 26.689661], [87.202871, 26.689017], [87.20238, 26.685508], [87.197896, 26.685331], [87.196699, 26.692133], [87.193571, 26.693006], [87.192716, 26.696151], [87.189677, 26.698211], [87.187434, 26.693661], [87.188966, 26.6924], [87.18845, 26.687438], [87.182926, 26.68636], [87.182227, 26.687565], [87.180461, 26.681661], [87.177369, 26.678519], [87.177089, 26.6748], [87.170227, 26.671079], [87.167771, 26.664117], [87.164453, 26.661661], [87.166389, 26.657499], [87.171884, 26.660004], [87.173449, 26.662439], [87.179281, 26.661661], [87.179321, 26.657661], [87.175259, 26.656629], [87.17604, 26.649661], [87.174227, 26.646133], [87.166227, 26.648703], [87.162227, 26.652808], [87.155878, 26.655313], [87.146227, 26.651958], [87.142776, 26.649661], [87.147039, 26.645661], [87.143205, 26.644683], [87.142583, 26.637305], [87.139151, 26.636738], [87.134673, 26.629215], [87.131238, 26.62865], [87.127472, 26.624416], [87.126736, 26.621152], [87.122227, 26.625463], [87.118227, 26.620804

# %% [markdown]
# ## Calculating percentages for all open test centres.

# %%
list_pop_ids = list(existing_labs['ID_30min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 17.0

# %%
list_pop_ids = list(existing_labs['ID_60min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 22.0

# %%
list_pop_ids = list(existing_labs['ID_30min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 35.0

# %%
list_pop_ids = list(existing_labs['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 62.0

# %% [markdown]
# ## Calculating percentages for test centres open in May 2021

# %%
initial_labs = existing_labs[existing_labs['Date Open']=='2021-05-01']

# %%
list_pop_ids = list(initial_labs['ID_30min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 16.0

# %%
list_pop_ids = list(initial_labs['ID_60min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 21.0

# %%
list_pop_ids = list(initial_labs['ID_30min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 33.0

# %%
list_pop_ids = list(initial_labs['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 55.0

# %% [markdown]
# ### 60 min driving shows the highest increase in percentage from 55 to 62%

# %%
df_relative_wealth_index = pd.read_csv('Data/npl_relative_wealth_index.csv')
def convert_Point(population):
    return Point(population['longitude'],population['latitude'])
df_relative_wealth_index['geometry'] = df_relative_wealth_index[['latitude','longitude']].apply(convert_Point,axis=1)
df_relative_wealth_index = gpd.GeoDataFrame(df_relative_wealth_index)
rwi_districts = gpd.sjoin(df_relative_wealth_index, districts_nepal, how="left", op="within")
rwi_districts = rwi_districts.groupby(['DISTRICT','Province'])['rwi'].mean().reset_index()
rwi_districts['rwi'] = rwi_districts['rwi'].round(2)
rwi_districts.columns = ['District','Province','Relative Wealth Index']

# %%
list_pop_ids = list(initial_labs['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]

district_analysis = population[population['ID'].isin(list_pop_ids)][['population','DISTRICT','Province']]
district_analysis.columns = ['Pop with Access','District','Province']
dt1 = district_analysis.groupby(['District','Province'])['Pop with Access'].sum().reset_index()

dt2 = population.groupby(['DISTRICT','Province'])['population'].sum().reset_index()
dt2.columns = ['District','Province','Total Population']

df_pop_access_dist = pd.merge(dt1,dt2,on=['District','Province'])
df_pop_access_dist['%'] = df_pop_access_dist['Pop with Access']*100/df_pop_access_dist['Total Population']
df_pop_access_dist['%'] = df_pop_access_dist['%'].round(2)

df_pop_access_dist = pd.merge(df_pop_access_dist,rwi_districts,on=['District','Province'])

fig = px.scatter(df_pop_access_dist,y='%',x='Relative Wealth Index',color='Province',size='Total Population')
fig.update_xaxes(title='Average Relative Wealth Index of District')
fig.update_yaxes(title='% of Population with Access')
fig.update_layout(plot_bgcolor='white',title='60 Min Driving for Initial set of 69 labs')
# Out:
# <div>                            <div id="b503ddfc-ab6a-41b1-9cf6-9e2d31488261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b503ddfc-ab6a-41b1-9cf6-9e2d31488261")) {                    Plotly.newPlot(                        "b503ddfc-ab6a-41b1-9cf6-9e2d31488261",                        [{"hovertemplate":"Province=5<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","size":[426169.0,328359.0,465037.0,192349.0,570025.0,265206.0,184929.0,173829.0,749009.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"5","orientation":"v","showlegend":true,"x":[-0.07,-0.12,-0.27,-0.1,-0.19,0.17,-0.16,-0.46,0.26],"xaxis":"x","y":[79.8,39.84,42.71,0.45,39.98,60.18,44.13,2.26,99.05],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=2<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"2","marker":{"color":"#EF553B","size":[569754.0,568677.0,503227.0,1412871.0,496724.0,853835.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"2","orientation":"v","showlegend":true,"x":[-0.02,0.21,0.11,0.18,0.13,0.18],"xaxis":"x","y":[61.71,83.7,56.78,77.23,83.33,2.67],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Bagmati<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Bagmati","marker":{"color":"#00cc96","size":[288209.0,497945.0,245610.0,110899.0,4981888.0,429168.0,325407.0,191851.0,30623.0,214301.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Bagmati","orientation":"v","showlegend":true,"x":[0.91,0.07,-0.15,0.03,0.93,0.21,-0.23,-0.1,-0.25,-0.05],"xaxis":"x","y":[100.0,78.11,14.96,50.0,99.44,92.45,49.7,57.69,30.89,0.34],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Sudur Pashchim<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Sudur Pashchim","marker":{"color":"#ab63fa","size":[113990.0,156794.0,1033059.0,1138681.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Sudur Pashchim","orientation":"v","showlegend":true,"x":[-0.4,-0.4,-0.29,-0.09],"xaxis":"x","y":[2.95,1.02,22.03,75.16],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=1<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"1","marker":{"color":"#FFA15A","size":[115105.0,217520.0,664405.0,846058.0,3091289.0,66646.0,252816.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"1","orientation":"v","showlegend":true,"x":[-0.27,-0.26,0.25,0.02,0.14,-0.22,-0.33],"xaxis":"x","y":[35.8,1.7,30.42,69.06,88.08,0.45,2.47],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Gandaki<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Gandaki","marker":{"color":"#19d3f3","size":[184656.0,363590.0,116519.0,255593.0,207424.0,238389.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Gandaki","orientation":"v","showlegend":true,"x":[-0.24,0.06,-0.24,-0.1,-0.01,-0.14],"xaxis":"x","y":[0.24,88.98,0.13,29.12,9.82,11.88],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Karnali<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Karnali","marker":{"color":"#FF6692","size":[93518.0,195162.0,151831.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Karnali","orientation":"v","showlegend":true,"x":[-0.4,-0.42,-0.37],"xaxis":"x","y":[17.23,0.02,31.2],"yaxis":"y","type":"scatter"}],                        {"t ...

# %%
list_pop_ids = list(existing_labs['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]

district_analysis = population[population['ID'].isin(list_pop_ids)][['population','DISTRICT','Province']]
district_analysis.columns = ['Pop with Access','District','Province']
dt1 = district_analysis.groupby(['District','Province'])['Pop with Access'].sum().reset_index()

dt2 = population.groupby(['DISTRICT','Province'])['population'].sum().reset_index()
dt2.columns = ['District','Province','Total Population']

df_pop_access_dist = pd.merge(dt1,dt2,on=['District','Province'])
df_pop_access_dist['%'] = df_pop_access_dist['Pop with Access']*100/df_pop_access_dist['Total Population']
df_pop_access_dist['%'] = df_pop_access_dist['%'].round(2)

df_pop_access_dist = pd.merge(df_pop_access_dist,rwi_districts,on=['District','Province'])

fig = px.scatter(df_pop_access_dist,y='%',x='Relative Wealth Index',color='Province',size='Total Population')
fig.update_xaxes(title='Average Relative Wealth Index of District')
fig.update_yaxes(title='% of Population with Access')
fig.update_layout(plot_bgcolor='white',title='60 Min Driving for all 89 labs')
# Out:
# <div>                            <div id="824246d5-ee42-4788-a600-9ad888ae7227" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("824246d5-ee42-4788-a600-9ad888ae7227")) {                    Plotly.newPlot(                        "824246d5-ee42-4788-a600-9ad888ae7227",                        [{"hovertemplate":"Province=Sudur Pashchim<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Sudur Pashchim","marker":{"color":"#636efa","size":[205429.0,113990.0,156794.0,1033059.0,1138681.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Sudur Pashchim","orientation":"v","showlegend":true,"x":[-0.4,-0.4,-0.4,-0.29,-0.09],"xaxis":"x","y":[15.47,2.95,1.02,22.03,75.16],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Gandaki<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Gandaki","marker":{"color":"#EF553B","size":[193357.0,184656.0,363590.0,116519.0,77992.0,255593.0,42167.0,207424.0,238389.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Gandaki","orientation":"v","showlegend":true,"x":[-0.17,-0.24,0.06,-0.24,-0.25,-0.1,-0.05,-0.01,-0.14],"xaxis":"x","y":[18.04,0.69,89.75,5.51,16.64,74.36,35.44,9.82,54.91],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=5<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"5","marker":{"color":"#00cc96","size":[426169.0,328359.0,465037.0,192349.0,570025.0,265206.0,184929.0,173829.0,749009.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"5","orientation":"v","showlegend":true,"x":[-0.07,-0.12,-0.27,-0.1,-0.19,0.17,-0.16,-0.46,0.26],"xaxis":"x","y":[79.8,39.84,42.71,0.45,39.98,81.7,44.13,2.26,99.05],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=2<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"2","marker":{"color":"#ab63fa","size":[569754.0,568677.0,503227.0,1412871.0,592824.0,496724.0,635842.0,853835.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"2","orientation":"v","showlegend":true,"x":[-0.02,0.21,0.11,0.18,-0.01,0.13,-0.03,0.18],"xaxis":"x","y":[81.65,89.38,69.67,77.23,50.34,83.33,65.98,70.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Bagmati<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Bagmati","marker":{"color":"#FFA15A","size":[288209.0,497945.0,245610.0,126236.0,110899.0,4981888.0,429168.0,325407.0,191851.0,30623.0,214301.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Bagmati","orientation":"v","showlegend":true,"x":[0.91,0.07,-0.15,-0.2,0.03,0.93,0.21,-0.23,-0.1,-0.25,-0.05],"xaxis":"x","y":[100.0,78.11,14.96,22.01,50.0,99.44,92.62,49.7,58.43,30.89,2.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Karnali<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Karnali","marker":{"color":"#19d3f3","size":[216454.0,93518.0,195162.0,151831.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Karnali","orientation":"v","showlegend":true,"x":[-0.39,-0.4,-0.42,-0.37],"xaxis":"x","y":[2.28,17.23,0.02,31.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=1<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"1","marker":{"color":"#FF6692","size":[115105.0,217520.0,664405.0,846058.0,3091289.0,66646.0,252816.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"1","orientation":"v","showlegend" ...

# %% [markdown]
# ### Data of potential locations as list of hospitals

# %%
potential_locations = gpd.read_file('Data/nepal_hospitals_osm.geojson')
potential_locations = potential_locations[['amenity','name','geometry']].reset_index()
potential_locations.columns = ['ID','Facility Type','Name','geometry']
potential_locations = potential_locations[potential_locations['Facility Type']=='hospital']
potential_locations['Latitude'] = potential_locations['geometry'].apply(lambda x:x.y)
potential_locations['Longitude'] = potential_locations['geometry'].apply(lambda x:x.x)

# %%
len(potential_locations)
# Out:
# 694

# %%
# %%time
potential_locations['isochrone_60min_driving'] = potential_locations[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="60",
                                                                                   access_token=access_token,
                                                                                   mode='driving',
                                                                                   axis=1)

potential_locations['isochrone_30min_driving'] = potential_locations[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="30",
                                                                                   access_token=access_token,
                                                                                   mode='driving',
                                                                                   axis=1)

potential_locations['isochrone_60min_walking'] = potential_locations[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="60",
                                                                                   access_token=access_token,
                                                                                   mode='walking',
                                                                                   axis=1)

potential_locations['isochrone_30min_walking'] = potential_locations[['Longitude','Latitude']].apply(get_isochrone,
                                                                                   minutes_list="30",
                                                                                   access_token=access_token,
                                                                                   mode='walking',
                                                                                   axis=1)
# Out:
# CPU times: user 11.3 s, sys: 1.08 s, total: 12.4 s
# Wall time: 44.8 s

# %%
# %%time

potential_locations['60min_driving'] = potential_locations['isochrone_60min_driving'].apply(lambda x: x[0]['geometry'])
potential_locations['60min_driving'] = potential_locations['60min_driving'].apply(lambda x:Polygon(x['coordinates'][0]))

potential_locations['30min_driving'] = potential_locations['isochrone_30min_driving'].apply(lambda x: x[0]['geometry'])
potential_locations['30min_driving'] = potential_locations['30min_driving'].apply(lambda x:Polygon(x['coordinates'][0]))

potential_locations['60min_walking'] = potential_locations['isochrone_60min_walking'].apply(lambda x: x[0]['geometry'])
potential_locations['60min_walking'] = potential_locations['60min_walking'].apply(lambda x:Polygon(x['coordinates'][0]))

potential_locations['30min_walking'] = potential_locations['isochrone_30min_walking'].apply(lambda x: x[0]['geometry'])
potential_locations['30min_walking'] = potential_locations['30min_walking'].apply(lambda x:Polygon(x['coordinates'][0]))
# Out:
# CPU times: user 355 ms, sys: 37.3 ms, total: 392 ms
# Wall time: 381 ms

# %%
# %%time

potential_locations['ID_60min_driving'] = potential_locations['60min_driving'].apply(get_population_within_vector,vector_layer=population)
potential_locations['ID_30min_driving'] = potential_locations['30min_driving'].apply(get_population_within_vector,vector_layer=population)
potential_locations['ID_60min_walking'] = potential_locations['60min_walking'].apply(get_population_within_vector,vector_layer=population)
potential_locations['ID_30min_walking'] = potential_locations['30min_walking'].apply(get_population_within_vector,vector_layer=population)
# Out:
# CPU times: user 1min 50s, sys: 356 ms, total: 1min 51s
# Wall time: 1min 51s

# %%
list_pop_ids = list(potential_locations['ID_30min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 21.0

# %%
list_pop_ids = list(potential_locations['ID_60min_walking'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 31.0

# %%
list_pop_ids = list(potential_locations['ID_30min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 54.0

# %%
list_pop_ids = list(potential_locations['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]
pop_with_access = list(set(list_pop_ids))

(population[population['ID'].isin(pop_with_access)]['population'].sum()*100/population['population'].sum()).round()
# Out:
# 80.0

# %%
list_pop_ids = list(potential_locations['ID_60min_driving'].values)
list_pop_ids = [item for sublist in list_pop_ids for item in sublist]

district_analysis = population[population['ID'].isin(list_pop_ids)][['population','DISTRICT','Province']]
district_analysis.columns = ['Pop with Access','District','Province']
dt1 = district_analysis.groupby(['District','Province'])['Pop with Access'].sum().reset_index()

dt2 = population.groupby(['DISTRICT','Province'])['population'].sum().reset_index()
dt2.columns = ['District','Province','Total Population']

df_pop_access_dist = pd.merge(dt1,dt2,on=['District','Province'])
df_pop_access_dist['%'] = df_pop_access_dist['Pop with Access']*100/df_pop_access_dist['Total Population']
df_pop_access_dist['%'] = df_pop_access_dist['%'].round(2)

df_pop_access_dist = pd.merge(df_pop_access_dist,rwi_districts,on=['District','Province'])

fig = px.scatter(df_pop_access_dist,y='%',x='Relative Wealth Index',color='Province',size='Total Population')
fig.update_xaxes(title='Average Relative Wealth Index of District')
fig.update_yaxes(title='% of Population with Access')
fig.update_layout(plot_bgcolor='white',title='60 Min Driving - Health Facility (Hospital) Access')
# Out:
# <div>                            <div id="49de5daa-43d3-456f-9430-f5ef3bb36003" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49de5daa-43d3-456f-9430-f5ef3bb36003")) {                    Plotly.newPlot(                        "49de5daa-43d3-456f-9430-f5ef3bb36003",                        [{"hovertemplate":"Province=Sudur Pashchim<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Sudur Pashchim","marker":{"color":"#636efa","size":[205429.0,192289.0,162067.0,118044.0,113990.0,102792.0,156794.0,1033059.0,1138681.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Sudur Pashchim","orientation":"v","showlegend":true,"x":[-0.4,-0.35,-0.41,-0.43,-0.4,-0.45,-0.4,-0.29,-0.09],"xaxis":"x","y":[35.95,5.75,26.15,9.49,17.17,12.3,5.72,83.81,78.69],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=5<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"5","marker":{"color":"#EF553B","size":[135563.0,426169.0,328359.0,465037.0,192349.0,570025.0,265206.0,184929.0,175042.0,173829.0,48639.0,749009.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"5","orientation":"v","showlegend":true,"x":[-0.18,-0.07,-0.12,-0.27,-0.1,-0.19,0.17,-0.16,-0.29,-0.46,-0.5,0.26],"xaxis":"x","y":[71.58,85.47,85.49,78.83,72.23,92.49,95.28,51.8,21.15,20.62,3.13,99.17],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Gandaki<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Gandaki","marker":{"color":"#00cc96","size":[193357.0,184656.0,363590.0,116519.0,3236.0,8644.0,77992.0,255593.0,42167.0,207424.0,238389.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Gandaki","orientation":"v","showlegend":true,"x":[-0.17,-0.24,0.06,-0.24,-0.39,-0.34,-0.25,-0.1,-0.05,-0.01,-0.14],"xaxis":"x","y":[33.57,69.82,93.53,71.5,7.94,4.2,21.85,83.81,85.44,83.9,74.66],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=2<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"2","marker":{"color":"#ab63fa","size":[569754.0,568677.0,503227.0,1412871.0,592824.0,496724.0,635842.0,853835.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"2","orientation":"v","showlegend":true,"x":[-0.02,0.21,0.11,0.18,-0.01,0.13,-0.03,0.18],"xaxis":"x","y":[71.26,96.98,98.97,83.01,78.1,94.12,91.98,97.87],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=Bagmati<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"Bagmati","marker":{"color":"#FFA15A","size":[288209.0,497945.0,245610.0,126236.0,110899.0,4981888.0,429168.0,325407.0,191851.0,141473.0,30623.0,199668.0,214301.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"Bagmati","orientation":"v","showlegend":true,"x":[0.91,0.07,-0.15,-0.2,0.03,0.93,0.21,-0.23,-0.1,-0.18,-0.25,-0.32,-0.05],"xaxis":"x","y":[100.0,87.44,79.83,68.22,61.2,99.49,97.18,62.5,71.49,41.46,49.2,41.71,55.58],"yaxis":"y","type":"scatter"},{"hovertemplate":"Province=1<br>Relative Wealth Index=%{x}<br>%=%{y}<br>Total Population=%{marker.size}<extra></extra>","legendgroup":"1","marker":{"color":"#19d3f3","size":[120661.0,115105.0,217520.0,664405.0,846058.0,101229.0,131604.0,113844.0,17380.0,3091289.0,88106.0,66646.0,252816.0],"sizemode":"area","sizeref":12454.72,"symbol":"circle"},"mode":"markers","name":"1","orientation":"v","showlegend":true,"x":[-0.38,-0.27,-0.26,0.25,0.02,-0.32,-0.26,-0.4,-0.39,0.14,-0.34,-0.22,-0.33],"xaxis":"x","y":[6.07,36.53,48.82,93.92,87.12,34.99,33.71,20.56,4.48,96.83,5.1,28.2,40 ...

# %%
existing_labs.to_pickle('Data/Results_Analytics/existing_labs.pkl')

# %%
potential_locations.to_pickle('Data/Results_Analytics/potential_locs_hospitals.pkl')

# %%
population.to_pickle('Data/Results_Analytics/population.pkl')
